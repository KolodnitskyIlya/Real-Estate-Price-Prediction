# %% [markdown]
# # Загрузка даннных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### **Описание датасета**

# %% [markdown]
# Цены квартир в Москве

# %% [markdown]
# Ваша задача этом соревновании - предсказать цены на квартиры в датасете test.csv. Вам будут даны два датасета: train.csv (содержит признаки и цены на квартиры) и test.csv (только признаки).

# %% [markdown]
# Метрика для оценки – Коэффициент детерминации:

# %% [markdown]
# * Id - идентификационный номер квартиры
#
# * DistrictId - идентификационный номер района
#
# * Rooms - количество комнат
#
# * Square - площадь
#
# * LifeSquare - жилая площадь
#
# * KitchenSquare - площадь кухни
#
# * Floor - этаж
#
# * HouseFloor - количество этажей в доме
#
# * HouseYear - год постройки дома
#
# * Ecology_1, Ecology_2, Ecology_3 - экологические показатели местности
#
# * Social_1, Social_2, Social_3 - социальные показатели местности
#
# * Healthcare_1, Helthcare_2 - показатели местности, связанные с охраной здоровья
#
# * Shops_1, Shops_2 - показатели, связанные с наличием магазинов, торговых центров
#
# * Price - цена квартиры

# %%
df_train = pd.read_csv('train.csv')
df_train
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0     14038          35    2.0  47.981561   29.442751            6.0      7
# 1     15053          41    3.0  65.683640   40.049543            8.0      7
# 2      4765          53    2.0  44.947953   29.197612            0.0      8
# 3      5809          58    2.0  53.352981   52.731512            9.0      8
# 4     10783          99    1.0  39.649192   23.776169            7.0     11
# ...     ...         ...    ...        ...         ...            ...    ...
# 9995     77          32    2.0  50.401785   30.476203            5.0      6
# 9996   6159          18    1.0  41.521546   20.539216            9.0     13
# 9997   5123          27    1.0  47.939008         NaN            1.0     12
# 9998   5400          75    2.0  43.602562   33.840147            8.0      1
# 9999   6306         128    1.0  38.666645   21.157874            8.0      7
#
# ...

# %%
df_test = pd.read_csv('test.csv')
df_test
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0       725          58    2.0  49.882643   33.432782            6.0      6
# 1     15856          74    2.0  69.263183         NaN            1.0      6
# 2      5480         190    1.0  13.597819   15.948246           12.0      2
# 3     15664          47    2.0  73.046609   51.940842            9.0     22
# 4     14275          27    1.0  47.527111   43.387569            1.0     17
# ...     ...         ...    ...        ...         ...            ...    ...
# 4995   8180          11    3.0  67.133911   50.809797            6.0      5
# 4996   4695           1    1.0  40.198472   21.807061           10.0     12
# 4997   5783          12    3.0  77.842178   48.282625            9.0     23
# 4998   4780          62    2.0  81.305222         NaN            0.0      4
# 4999  12504          30    2.0  60.555693         NaN            1.0     10
#
# ...

# %%
df_test.loc[:, 'Id'].values
# Out:
# array([  725, 15856,  5480, ...,  5783,  4780, 12504])

# %%
Id_df = pd.DataFrame(df_test.loc[:, 'Id'], columns=['Id'])
Id_df
# Out:
#          Id
# 0       725
# 1     15856
# 2      5480
# 3     15664
# 4     14275
# ...     ...
# 4995   8180
# 4996   4695
# 4997   5783
# 4998   4780
# 4999  12504
#
# [5000 rows x 1 columns]

# %%
df_train.set_index('Id', inplace=True)
df_train
# Out:
#        DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# Id
# 14038          35    2.0  47.981561   29.442751            6.0      7
# 15053          41    3.0  65.683640   40.049543            8.0      7
# 4765           53    2.0  44.947953   29.197612            0.0      8
# 5809           58    2.0  53.352981   52.731512            9.0      8
# 10783          99    1.0  39.649192   23.776169            7.0     11
# ...           ...    ...        ...         ...            ...    ...
# 77             32    2.0  50.401785   30.476203            5.0      6
# 6159           18    1.0  41.521546   20.539216            9.0     13
# 5123           27    1.0  47.939008         NaN            1.0     12
# 5400           75    2.0  43.602562   33.840147            8.0      1
# 6306          128    1.0  38.666645   21.157874            8.0      7
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# Id
# ...

# %%
df_test.set_index('Id', inplace=True)
df_test
# Out:
#        DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# Id
# 725            58    2.0  49.882643   33.432782            6.0      6
# 15856          74    2.0  69.263183         NaN            1.0      6
# 5480          190    1.0  13.597819   15.948246           12.0      2
# 15664          47    2.0  73.046609   51.940842            9.0     22
# 14275          27    1.0  47.527111   43.387569            1.0     17
# ...           ...    ...        ...         ...            ...    ...
# 8180           11    3.0  67.133911   50.809797            6.0      5
# 4695            1    1.0  40.198472   21.807061           10.0     12
# 5783           12    3.0  77.842178   48.282625            9.0     23
# 4780           62    2.0  81.305222         NaN            0.0      4
# 12504          30    2.0  60.555693         NaN            1.0     10
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# Id
# ...

# %%
y_train= df_train.iloc[:, -1]
y_train = pd.DataFrame(y_train, columns=['Price'])
y_train
# Out:
#                Price
# Id
# 14038  184966.930730
# 15053  300009.450063
# 4765   220925.908524
# 5809   175616.227217
# 10783  150226.531644
# ...              ...
# 77     196684.316040
# 6159   189050.289571
# 5123   159143.805370
# 5400   181595.339808
# 6306   218714.077615
#
# [10000 rows x 1 columns]

# %%
df_train.drop('Price', axis=1, inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# # Очистка данных и обработка выбросов

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 14038 to 6306
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DistrictId     10000 non-null  int64
#  1   Rooms          10000 non-null  float64
#  2   Square         10000 non-null  float64
#  3   LifeSquare     7887 non-null   float64
#  4   KitchenSquare  10000 non-null  float64
#  5   Floor          10000 non-null  int64
#  6   HouseFloor     10000 non-null  float64
#  7   HouseYear      10000 non-null  int64
#  8   Ecology_1      10000 non-null  float64
#  9   Ecology_2      10000 non-null  object
#  10  Ecology_3      10000 non-null  object
#  11  Social_1       10000 non-null  int64
#  12  Social_2       10000 non-null  int64
#  13  Social_3       10000 non-null  int64
#  14  Healthcare_1   5202 non-null   float64
#  15  Helthcare_2    10000 non-null  int64
#  16  Shops_1        10000 non-null  int64
# ...

# %%
df_train
# Out:
#        DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# Id
# 14038          35    2.0  47.981561   29.442751            6.0      7
# 15053          41    3.0  65.683640   40.049543            8.0      7
# 4765           53    2.0  44.947953   29.197612            0.0      8
# 5809           58    2.0  53.352981   52.731512            9.0      8
# 10783          99    1.0  39.649192   23.776169            7.0     11
# ...           ...    ...        ...         ...            ...    ...
# 77             32    2.0  50.401785   30.476203            5.0      6
# 6159           18    1.0  41.521546   20.539216            9.0     13
# 5123           27    1.0  47.939008         NaN            1.0     12
# 5400           75    2.0  43.602562   33.840147            8.0      1
# 6306          128    1.0  38.666645   21.157874            8.0      7
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# Id
# ...

# %%
df_train.describe()
# Out:
#          DistrictId         Rooms        Square   LifeSquare  KitchenSquare  \
# count  10000.000000  10000.000000  10000.000000  7887.000000   10000.000000
# mean      50.400800      1.890500     56.315775    37.199645       6.273300
# std       43.587592      0.839512     21.058732    86.241209      28.560917
# min        0.000000      0.000000      1.136859     0.370619       0.000000
# 25%       20.000000      1.000000     41.774881    22.769832       1.000000
# 50%       36.000000      2.000000     52.513310    32.781260       6.000000
# 75%       75.000000      2.000000     65.900625    45.128803       9.000000
# max      209.000000     19.000000    641.065193  7480.592129    2014.000000
#
#               Floor    HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.000000  10000.000000  1.000000e+04  10000.000000  10000.000000
# mean       8.526700     12.609400  3.990166e+03      0.118858     24.687000
# ...

# %%
df_test
# Out:
#        DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# Id
# 725            58    2.0  49.882643   33.432782            6.0      6
# 15856          74    2.0  69.263183         NaN            1.0      6
# 5480          190    1.0  13.597819   15.948246           12.0      2
# 15664          47    2.0  73.046609   51.940842            9.0     22
# 14275          27    1.0  47.527111   43.387569            1.0     17
# ...           ...    ...        ...         ...            ...    ...
# 8180           11    3.0  67.133911   50.809797            6.0      5
# 4695            1    1.0  40.198472   21.807061           10.0     12
# 5783           12    3.0  77.842178   48.282625            9.0     23
# 4780           62    2.0  81.305222         NaN            0.0      4
# 12504          30    2.0  60.555693         NaN            1.0     10
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# Id
# ...

# %%
df_test.describe()
# Out:
#         DistrictId        Rooms       Square   LifeSquare  KitchenSquare  \
# count  5000.000000  5000.000000  5000.000000  3959.000000    5000.000000
# mean     51.279200     1.910000    56.449500    36.158810       5.976800
# std      44.179466     0.838594    19.092787    17.825287       9.950018
# min       0.000000     0.000000     1.378543     0.333490       0.000000
# 25%      21.000000     1.000000    41.906231    23.092026       1.000000
# 50%      37.000000     2.000000    52.921340    32.925087       6.000000
# 75%      77.000000     2.000000    66.285129    45.174091       9.000000
# max     212.000000    17.000000   223.453689   303.071094     620.000000
#
#              Floor   HouseFloor    HouseYear    Ecology_1     Social_1  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      8.632000    12.601000  1984.392600     0.119874    24.933800
# std       5.483228     6.789213    18.573149     0.120070    17.532202
# ...

# %% [markdown]
# ## Обработка выбросов и Feature engineering

# %% [markdown]
# ### Rooms

# %% [markdown]
# На рынке недвижимости представлены квартиры с разным количеством комнат, но максимальное количество комнат, как правило, не превышает 8 или 9.

# %%
np.sort(df_train['Rooms'].unique())
# Out:
# array([ 0.,  1.,  2.,  3.,  4.,  5.,  6., 10., 19.])

# %%
df_train['Rooms'].value_counts().sort_index()
# Out:
# Rooms
# 0.0        8
# 1.0     3705
# 2.0     3880
# 3.0     2235
# 4.0      150
# 5.0       18
# 6.0        1
# 10.0       2
# 19.0       1
# Name: count, dtype: int64

# %%
plt.bar(df_train['Rooms'].value_counts().sort_index().index, df_train['Rooms'].value_counts().sort_index().values)
plt.yscale('log')
plt.xlabel('Количество квартир')
plt.ylabel('Плотность квартир в Москве')
plt.show()

# %% [markdown]
# Заменяем 0 квартир на 1 и больше 9 на 9

# %%
df_train['СorrectedRooms'] = 0
df_test['СorrectedRooms'] = 0

# %%
df_train.loc[(df_train['Rooms'] == 0), 'СorrectedRooms'] = 1
df_train.loc[(df_train['Rooms'] == 0), 'Rooms'] = 1

# %%
df_train.loc[(df_train['Rooms'] > 9), 'СorrectedRooms'] = 1
df_train.loc[(df_train['Rooms'] > 9), 'Rooms'] = 9

# %%
df_test.loc[(df_test['Rooms'] == 0), 'СorrectedRooms'] = 1
df_test.loc[(df_test['Rooms'] == 0), 'Rooms'] = 1

# %%
df_test.loc[(df_test['Rooms'] > 9), 'СorrectedRooms'] = 1
df_test.loc[(df_test['Rooms'] > 9), 'Rooms'] = 9

# %%
df_test.describe()
# Out:
#         DistrictId        Rooms       Square   LifeSquare  KitchenSquare  \
# count  5000.000000  5000.000000  5000.000000  3959.000000    5000.000000
# mean     51.279200     1.908800    56.449500    36.158810       5.976800
# std      44.179466     0.816465    19.092787    17.825287       9.950018
# min       0.000000     1.000000     1.378543     0.333490       0.000000
# 25%      21.000000     1.000000    41.906231    23.092026       1.000000
# 50%      37.000000     2.000000    52.921340    32.925087       6.000000
# 75%      77.000000     2.000000    66.285129    45.174091       9.000000
# max     212.000000     9.000000   223.453689   303.071094     620.000000
#
#              Floor   HouseFloor    HouseYear    Ecology_1     Social_1  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      8.632000    12.601000  1984.392600     0.119874    24.933800
# std       5.483228     6.789213    18.573149     0.120070    17.532202
# ...

# %%
df_train.describe()
# Out:
#          DistrictId        Rooms        Square   LifeSquare  KitchenSquare  \
# count  10000.000000  10000.00000  10000.000000  7887.000000   10000.000000
# mean      50.400800      1.89010     56.315775    37.199645       6.273300
# std       43.587592      0.82176     21.058732    86.241209      28.560917
# min        0.000000      1.00000      1.136859     0.370619       0.000000
# 25%       20.000000      1.00000     41.774881    22.769832       1.000000
# 50%       36.000000      2.00000     52.513310    32.781260       6.000000
# 75%       75.000000      2.00000     65.900625    45.128803       9.000000
# max      209.000000      9.00000    641.065193  7480.592129    2014.000000
#
#               Floor    HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.000000  10000.000000  1.000000e+04  10000.000000  10000.000000
# mean       8.526700     12.609400  3.990166e+03      0.118858     24.687000
# ...

# %% [markdown]
# ### HouseYear

# %%
df_train['HouseYear'].value_counts().sort_index()
# Out:
# HouseYear
# 1910          1
# 1912          2
# 1914          1
# 1916          1
# 1917          3
#            ...
# 2018        175
# 2019         79
# 2020         19
# 4968          1
# 20052011      1
# Name: count, Length: 97, dtype: int64

# %%
df_train['СorrectedHouseYear'] = 0
df_test['СorrectedHouseYear'] = 0

# %%
df_train.loc[(df_train['HouseYear'] > 2020), 'СorrectedHouseYear'] = 1
df_train.loc[(df_train['HouseYear'] > 2020), 'HouseYear'] = 2020

# %%
df_test['HouseYear'].value_counts().sort_index()
# Out:
# HouseYear
# 1908      1
# 1909      1
# 1910      1
# 1911      1
# 1912      1
#        ...
# 2016    172
# 2017    141
# 2018     73
# 2019     28
# 2020      9
# Name: count, Length: 97, dtype: int64

# %%
df_train.describe()
# Out:
#          DistrictId        Rooms        Square   LifeSquare  KitchenSquare  \
# count  10000.000000  10000.00000  10000.000000  7887.000000   10000.000000
# mean      50.400800      1.89010     56.315775    37.199645       6.273300
# std       43.587592      0.82176     21.058732    86.241209      28.560917
# min        0.000000      1.00000      1.136859     0.370619       0.000000
# 25%       20.000000      1.00000     41.774881    22.769832       1.000000
# 50%       36.000000      2.00000     52.513310    32.781260       6.000000
# 75%       75.000000      2.00000     65.900625    45.128803       9.000000
# max      209.000000      9.00000    641.065193  7480.592129    2014.000000
#
#               Floor    HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       8.526700     12.609400   1984.872400      0.118858     24.687000
# ...

# %%
df_test.describe()
# Out:
#         DistrictId        Rooms       Square   LifeSquare  KitchenSquare  \
# count  5000.000000  5000.000000  5000.000000  3959.000000    5000.000000
# mean     51.279200     1.908800    56.449500    36.158810       5.976800
# std      44.179466     0.816465    19.092787    17.825287       9.950018
# min       0.000000     1.000000     1.378543     0.333490       0.000000
# 25%      21.000000     1.000000    41.906231    23.092026       1.000000
# 50%      37.000000     2.000000    52.921340    32.925087       6.000000
# 75%      77.000000     2.000000    66.285129    45.174091       9.000000
# max     212.000000     9.000000   223.453689   303.071094     620.000000
#
#              Floor   HouseFloor    HouseYear    Ecology_1     Social_1  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      8.632000    12.601000  1984.392600     0.119874    24.933800
# std       5.483228     6.789213    18.573149     0.120070    17.532202
# ...

# %% [markdown]
# ### HouseFloor

# %%
df_train['СorrectedHouseFloor'] = 0
df_test['СorrectedHouseFloor'] = 0

# %%
df_train.loc[(df_train['HouseFloor'] == 0), 'СorrectedHouseFloor'] = 1
df_train.loc[(df_train['HouseFloor'] == 0), 'HouseFloor'] = 1

# %%
df_test.loc[(df_test['HouseFloor'] == 0), 'СorrectedHouseFloor'] = 1
df_test.loc[(df_test['HouseFloor'] == 0), 'HouseFloor'] = 1

# %%
df_train.describe()
# Out:
#          DistrictId        Rooms        Square   LifeSquare  KitchenSquare  \
# count  10000.000000  10000.00000  10000.000000  7887.000000   10000.000000
# mean      50.400800      1.89010     56.315775    37.199645       6.273300
# std       43.587592      0.82176     21.058732    86.241209      28.560917
# min        0.000000      1.00000      1.136859     0.370619       0.000000
# 25%       20.000000      1.00000     41.774881    22.769832       1.000000
# 50%       36.000000      2.00000     52.513310    32.781260       6.000000
# 75%       75.000000      2.00000     65.900625    45.128803       9.000000
# max      209.000000      9.00000    641.065193  7480.592129    2014.000000
#
#               Floor   HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.000000  10000.00000  10000.000000  10000.000000  10000.000000
# mean       8.526700     12.63630   1984.872400      0.118858     24.687000
# ...

# %%
df_test.describe()
# Out:
#         DistrictId        Rooms       Square   LifeSquare  KitchenSquare  \
# count  5000.000000  5000.000000  5000.000000  3959.000000    5000.000000
# mean     51.279200     1.908800    56.449500    36.158810       5.976800
# std      44.179466     0.816465    19.092787    17.825287       9.950018
# min       0.000000     1.000000     1.378543     0.333490       0.000000
# 25%      21.000000     1.000000    41.906231    23.092026       1.000000
# 50%      37.000000     2.000000    52.921340    32.925087       6.000000
# 75%      77.000000     2.000000    66.285129    45.174091       9.000000
# max     212.000000     9.000000   223.453689   303.071094     620.000000
#
#              Floor   HouseFloor    HouseYear    Ecology_1     Social_1  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      8.632000    12.627200  1984.392600     0.119874    24.933800
# std       5.483228     6.742293    18.573149     0.120070    17.532202
# ...

# %% [markdown]
# ### Floor

# %%
df_train['СorrectedFloor'] = 0
df_test['СorrectedFloor'] = 0

# %%
df_train.loc[(df_train['Floor'] > df_train['HouseFloor'])]
# Out:
#        DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# Id
# 11993          74    2.0   80.312926         NaN            0.0     14
# 10953          27    1.0   53.769097   52.408027            1.0      5
# 2119           27    2.0   49.360648   31.993964            5.0      6
# 11935          27    2.0   64.711835         NaN            1.0     15
# 6641           54    3.0  118.907612         NaN            0.0      2
# ...           ...    ...         ...         ...            ...    ...
# 2237           52    3.0   64.074977   47.633428            6.0     11
# 16159          27    1.0   38.968338         NaN            1.0     10
# 4145           96    3.0   90.055233   47.860231           11.0     26
# 11553           3    3.0  101.622794   51.628780           12.0     18
# 77             32    2.0   50.401785   30.476203            5.0      6
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2  ... Social_2  Social_3  \
# ...

# %%
df_train.loc[(df_train['Floor'] > df_train['HouseFloor']), 'СorrectedFloor'] = 1
df_train.loc[(df_train['Floor'] > df_train['HouseFloor']), 'Floor'] = df_train.loc[(df_train['Floor'] > df_train['HouseFloor']), 'HouseFloor']

# %%
df_test.loc[(df_test['Floor'] > df_test['HouseFloor']), 'СorrectedFloor'] = 1
df_test.loc[(df_test['Floor'] > df_test['HouseFloor']), 'Floor'] = df_test.loc[(df_test['Floor'] > df_test['HouseFloor']), 'HouseFloor']

# %%
df_test
# Out:
#        DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# Id
# 725            58    2.0  49.882643   33.432782            6.0      6
# 15856          74    2.0  69.263183         NaN            1.0      1
# 5480          190    1.0  13.597819   15.948246           12.0      2
# 15664          47    2.0  73.046609   51.940842            9.0     22
# 14275          27    1.0  47.527111   43.387569            1.0     17
# ...           ...    ...        ...         ...            ...    ...
# 8180           11    3.0  67.133911   50.809797            6.0      5
# 4695            1    1.0  40.198472   21.807061           10.0     12
# 5783           12    3.0  77.842178   48.282625            9.0     22
# 4780           62    2.0  81.305222         NaN            0.0      1
# 12504          30    2.0  60.555693         NaN            1.0     10
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2  ... Social_2  Social_3  \
# ...

# %%
df_train
# Out:
#        DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# Id
# 14038          35    2.0  47.981561   29.442751            6.0      7
# 15053          41    3.0  65.683640   40.049543            8.0      7
# 4765           53    2.0  44.947953   29.197612            0.0      8
# 5809           58    2.0  53.352981   52.731512            9.0      8
# 10783          99    1.0  39.649192   23.776169            7.0     11
# ...           ...    ...        ...         ...            ...    ...
# 77             32    2.0  50.401785   30.476203            5.0      5
# 6159           18    1.0  41.521546   20.539216            9.0     13
# 5123           27    1.0  47.939008         NaN            1.0     12
# 5400           75    2.0  43.602562   33.840147            8.0      1
# 6306          128    1.0  38.666645   21.157874            8.0      7
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2  ... Social_2  Social_3  \
# ...

# %%
df_test.describe()
# Out:
#         DistrictId        Rooms       Square   LifeSquare  KitchenSquare  \
# count  5000.000000  5000.000000  5000.000000  3959.000000    5000.000000
# mean     51.279200     1.908800    56.449500    36.158810       5.976800
# std      44.179466     0.816465    19.092787    17.825287       9.950018
# min       0.000000     1.000000     1.378543     0.333490       0.000000
# 25%      21.000000     1.000000    41.906231    23.092026       1.000000
# 50%      37.000000     2.000000    52.921340    32.925087       6.000000
# 75%      77.000000     2.000000    66.285129    45.174091       9.000000
# max     212.000000     9.000000   223.453689   303.071094     620.000000
#
#             Floor   HouseFloor    HouseYear    Ecology_1     Social_1  \
# count  5000.00000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      7.86420    12.627200  1984.392600     0.119874    24.933800
# std       5.41956     6.742293    18.573149     0.120070    17.532202
# ...

# %%
df_train.describe()
# Out:
#          DistrictId        Rooms        Square   LifeSquare  KitchenSquare  \
# count  10000.000000  10000.00000  10000.000000  7887.000000   10000.000000
# mean      50.400800      1.89010     56.315775    37.199645       6.273300
# std       43.587592      0.82176     21.058732    86.241209      28.560917
# min        0.000000      1.00000      1.136859     0.370619       0.000000
# 25%       20.000000      1.00000     41.774881    22.769832       1.000000
# 50%       36.000000      2.00000     52.513310    32.781260       6.000000
# 75%       75.000000      2.00000     65.900625    45.128803       9.000000
# max      209.000000      9.00000    641.065193  7480.592129    2014.000000
#
#               Floor   HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.000000  10000.00000  10000.000000  10000.000000  10000.000000
# mean       7.727300     12.63630   1984.872400      0.118858     24.687000
# ...

# %% [markdown]
# ### AnnualIntervals - годовые промежутки

# %%
df_train['AnnualIntervals'] = 0
df_test['AnnualIntervals'] = 0

# %%
df_train.loc[((df_train['HouseYear'] > 1900) & (df_train['HouseYear'] < 1920)), 'AnnualIntervals'] = 1
df_train.loc[((df_train['HouseYear'] >= 1920) & (df_train['HouseYear'] < 1930)), 'AnnualIntervals'] = 2
df_train.loc[((df_train['HouseYear'] >= 1930) & (df_train['HouseYear'] < 1950)), 'AnnualIntervals'] = 3
df_train.loc[((df_train['HouseYear'] >= 1950) & (df_train['HouseYear'] < 1980)), 'AnnualIntervals'] = 4
df_train.loc[((df_train['HouseYear'] >= 1980) & (df_train['HouseYear'] < 1990)), 'AnnualIntervals'] = 5
df_train.loc[((df_train['HouseYear'] >= 1990) & (df_train['HouseYear'] < 2000)), 'AnnualIntervals'] = 6
df_train.loc[((df_train['HouseYear'] >= 2000) & (df_train['HouseYear'] < 2010)), 'AnnualIntervals'] = 7
df_train.loc[((df_train['HouseYear'] >= 2010) & (df_train['HouseYear'] < 2021)), 'AnnualIntervals'] = 8

# %%
df_test.loc[((df_test['HouseYear'] > 1900) & (df_test['HouseYear'] < 1920)), 'AnnualIntervals'] = 1
df_test.loc[((df_test['HouseYear'] >= 1920) & (df_test['HouseYear'] < 1930)), 'AnnualIntervals'] = 2
df_test.loc[((df_test['HouseYear'] >= 1930) & (df_test['HouseYear'] < 1950)), 'AnnualIntervals'] = 3
df_test.loc[((df_test['HouseYear'] >= 1950) & (df_test['HouseYear'] < 1980)), 'AnnualIntervals'] = 4
df_test.loc[((df_test['HouseYear'] >= 1980) & (df_test['HouseYear'] < 1990)), 'AnnualIntervals'] = 5
df_test.loc[((df_test['HouseYear'] >= 1990) & (df_test['HouseYear'] < 2000)), 'AnnualIntervals'] = 6
df_test.loc[((df_test['HouseYear'] >= 2000) & (df_test['HouseYear'] < 2010)), 'AnnualIntervals'] = 7
df_test.loc[((df_test['HouseYear'] >= 2010) & (df_test['HouseYear'] < 2021)), 'AnnualIntervals'] = 8

# %%
df_test
# Out:
#        DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# Id
# 725            58    2.0  49.882643   33.432782            6.0      6
# 15856          74    2.0  69.263183         NaN            1.0      1
# 5480          190    1.0  13.597819   15.948246           12.0      2
# 15664          47    2.0  73.046609   51.940842            9.0     22
# 14275          27    1.0  47.527111   43.387569            1.0     17
# ...           ...    ...        ...         ...            ...    ...
# 8180           11    3.0  67.133911   50.809797            6.0      5
# 4695            1    1.0  40.198472   21.807061           10.0     12
# 5783           12    3.0  77.842178   48.282625            9.0     22
# 4780           62    2.0  81.305222         NaN            0.0      1
# 12504          30    2.0  60.555693         NaN            1.0     10
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2  ... Social_3  Healthcare_1  \
# ...

# %%
df_train
# Out:
#        DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# Id
# 14038          35    2.0  47.981561   29.442751            6.0      7
# 15053          41    3.0  65.683640   40.049543            8.0      7
# 4765           53    2.0  44.947953   29.197612            0.0      8
# 5809           58    2.0  53.352981   52.731512            9.0      8
# 10783          99    1.0  39.649192   23.776169            7.0     11
# ...           ...    ...        ...         ...            ...    ...
# 77             32    2.0  50.401785   30.476203            5.0      5
# 6159           18    1.0  41.521546   20.539216            9.0     13
# 5123           27    1.0  47.939008         NaN            1.0     12
# 5400           75    2.0  43.602562   33.840147            8.0      1
# 6306          128    1.0  38.666645   21.157874            8.0      7
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2  ... Social_3  Healthcare_1  \
# ...

# %%
df_train.describe()
# Out:
#          DistrictId        Rooms        Square   LifeSquare  KitchenSquare  \
# count  10000.000000  10000.00000  10000.000000  7887.000000   10000.000000
# mean      50.400800      1.89010     56.315775    37.199645       6.273300
# std       43.587592      0.82176     21.058732    86.241209      28.560917
# min        0.000000      1.00000      1.136859     0.370619       0.000000
# 25%       20.000000      1.00000     41.774881    22.769832       1.000000
# 50%       36.000000      2.00000     52.513310    32.781260       6.000000
# 75%       75.000000      2.00000     65.900625    45.128803       9.000000
# max      209.000000      9.00000    641.065193  7480.592129    2014.000000
#
#               Floor   HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.000000  10000.00000  10000.000000  10000.000000  10000.000000
# mean       7.727300     12.63630   1984.872400      0.118858     24.687000
# ...

# %%
df_test.describe()
# Out:
#         DistrictId        Rooms       Square   LifeSquare  KitchenSquare  \
# count  5000.000000  5000.000000  5000.000000  3959.000000    5000.000000
# mean     51.279200     1.908800    56.449500    36.158810       5.976800
# std      44.179466     0.816465    19.092787    17.825287       9.950018
# min       0.000000     1.000000     1.378543     0.333490       0.000000
# 25%      21.000000     1.000000    41.906231    23.092026       1.000000
# 50%      37.000000     2.000000    52.921340    32.925087       6.000000
# 75%      77.000000     2.000000    66.285129    45.174091       9.000000
# max     212.000000     9.000000   223.453689   303.071094     620.000000
#
#             Floor   HouseFloor    HouseYear    Ecology_1     Social_1  \
# count  5000.00000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      7.86420    12.627200  1984.392600     0.119874    24.933800
# std       5.41956     6.742293    18.573149     0.120070    17.532202
# ...

# %% [markdown]
# ### Square

# %%
df_train['CorrectedSquare'] = 0
df_test['CorrectedSquare'] = 0

# %%
df_train.loc[(df_train['Square'] < 10), 'CorrectedSquare'] = 1
df_train.loc[(df_train['Square'] < 10), 'Square'] = 10

# %%
df_test.loc[(df_test['Square'] < 10), 'CorrectedSquare'] = 1
df_test.loc[(df_test['Square'] < 10), 'Square'] = 10

# %%
df_train.describe()
# Out:
#          DistrictId        Rooms        Square   LifeSquare  KitchenSquare  \
# count  10000.000000  10000.00000  10000.000000  7887.000000   10000.000000
# mean      50.400800      1.89010     56.323334    37.199645       6.273300
# std       43.587592      0.82176     21.040914    86.241209      28.560917
# min        0.000000      1.00000     10.000000     0.370619       0.000000
# 25%       20.000000      1.00000     41.774881    22.769832       1.000000
# 50%       36.000000      2.00000     52.513310    32.781260       6.000000
# 75%       75.000000      2.00000     65.900625    45.128803       9.000000
# max      209.000000      9.00000    641.065193  7480.592129    2014.000000
#
#               Floor   HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.000000  10000.00000  10000.000000  10000.000000  10000.000000
# mean       7.727300     12.63630   1984.872400      0.118858     24.687000
# ...

# %%
df_train.describe()
# Out:
#          DistrictId        Rooms        Square   LifeSquare  KitchenSquare  \
# count  10000.000000  10000.00000  10000.000000  7887.000000   10000.000000
# mean      50.400800      1.89010     56.323334    37.199645       6.273300
# std       43.587592      0.82176     21.040914    86.241209      28.560917
# min        0.000000      1.00000     10.000000     0.370619       0.000000
# 25%       20.000000      1.00000     41.774881    22.769832       1.000000
# 50%       36.000000      2.00000     52.513310    32.781260       6.000000
# 75%       75.000000      2.00000     65.900625    45.128803       9.000000
# max      209.000000      9.00000    641.065193  7480.592129    2014.000000
#
#               Floor   HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.000000  10000.00000  10000.000000  10000.000000  10000.000000
# mean       7.727300     12.63630   1984.872400      0.118858     24.687000
# ...

# %% [markdown]
# ### KitchenSquare

# %% [markdown]
# #### Сначала установим верхнюю границу

# %%
df_train['CorrectedMaxKitchenSquare'] = 0
df_test['CorrectedMaxKitchenSquare'] = 0

# %%
df_train.loc[(df_train['KitchenSquare'] > 30), 'CorrectedMaxKitchenSquare'] = 1
df_train.loc[(df_train['KitchenSquare'] > 30), 'KitchenSquare'] = 30

# %%
df_test.loc[(df_test['KitchenSquare'] > 30), 'CorrectedMaxKitchenSquare'] = 1
df_test.loc[(df_test['KitchenSquare'] > 30), 'KitchenSquare'] = 30

# %%
df_train.describe()
# Out:
#          DistrictId        Rooms        Square   LifeSquare  KitchenSquare  \
# count  10000.000000  10000.00000  10000.000000  7887.000000    10000.00000
# mean      50.400800      1.89010     56.323334    37.199645        5.78510
# std       43.587592      0.82176     21.040914    86.241209        4.19503
# min        0.000000      1.00000     10.000000     0.370619        0.00000
# 25%       20.000000      1.00000     41.774881    22.769832        1.00000
# 50%       36.000000      2.00000     52.513310    32.781260        6.00000
# 75%       75.000000      2.00000     65.900625    45.128803        9.00000
# max      209.000000      9.00000    641.065193  7480.592129       30.00000
#
#               Floor   HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.000000  10000.00000  10000.000000  10000.000000  10000.000000
# mean       7.727300     12.63630   1984.872400      0.118858     24.687000
# ...

# %%
df_test.describe()
# Out:
#         DistrictId        Rooms       Square   LifeSquare  KitchenSquare  \
# count  5000.000000  5000.000000  5000.000000  3959.000000    5000.000000
# mean     51.279200     1.908800    56.460103    36.158810       5.782400
# std      44.179466     0.816465    19.065028    17.825287       4.074699
# min       0.000000     1.000000    10.000000     0.333490       0.000000
# 25%      21.000000     1.000000    41.906231    23.092026       1.000000
# 50%      37.000000     2.000000    52.921340    32.925087       6.000000
# 75%      77.000000     2.000000    66.285129    45.174091       9.000000
# max     212.000000     9.000000   223.453689   303.071094      30.000000
#
#             Floor   HouseFloor    HouseYear    Ecology_1     Social_1  ...  \
# count  5000.00000  5000.000000  5000.000000  5000.000000  5000.000000  ...
# mean      7.86420    12.627200  1984.392600     0.119874    24.933800  ...
# std       5.41956     6.742293    18.573149     0.120070    17.532202  ...
# ...

# %% [markdown]
# #### Теперь установим нижнюю границу

# %%
df_train['CorrectedMinKitchenSquare'] = 0
df_test['CorrectedMinKitchenSquare'] = 0

# %%
df_train.loc[(df_train['KitchenSquare'] < 4), 'CorrectedMinKitchenSquare'] = 1
df_train.loc[(df_train['KitchenSquare'] < 4), 'KitchenSquare'] = 4

# %%
df_test.loc[(df_test['KitchenSquare'] < 4), 'CorrectedMinKitchenSquare'] = 1
df_test.loc[(df_test['KitchenSquare'] < 4), 'KitchenSquare'] = 4

# %%
df_train.describe()
# Out:
#          DistrictId        Rooms        Square   LifeSquare  KitchenSquare  \
# count  10000.000000  10000.00000  10000.000000  7887.000000   10000.000000
# mean      50.400800      1.89010     56.323334    37.199645       6.804900
# std       43.587592      0.82176     21.040914    86.241209       3.095738
# min        0.000000      1.00000     10.000000     0.370619       4.000000
# 25%       20.000000      1.00000     41.774881    22.769832       4.000000
# 50%       36.000000      2.00000     52.513310    32.781260       6.000000
# 75%       75.000000      2.00000     65.900625    45.128803       9.000000
# max      209.000000      9.00000    641.065193  7480.592129      30.000000
#
#               Floor   HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.000000  10000.00000  10000.000000  10000.000000  10000.000000
# mean       7.727300     12.63630   1984.872400      0.118858     24.687000
# ...

# %%
df_test.describe()
# Out:
#         DistrictId        Rooms       Square   LifeSquare  KitchenSquare  \
# count  5000.000000  5000.000000  5000.000000  3959.000000    5000.000000
# mean     51.279200     1.908800    56.460103    36.158810       6.768800
# std      44.179466     0.816465    19.065028    17.825287       2.981799
# min       0.000000     1.000000    10.000000     0.333490       4.000000
# 25%      21.000000     1.000000    41.906231    23.092026       4.000000
# 50%      37.000000     2.000000    52.921340    32.925087       6.000000
# 75%      77.000000     2.000000    66.285129    45.174091       9.000000
# max     212.000000     9.000000   223.453689   303.071094      30.000000
#
#             Floor   HouseFloor    HouseYear    Ecology_1     Social_1  ...  \
# count  5000.00000  5000.000000  5000.000000  5000.000000  5000.000000  ...
# mean      7.86420    12.627200  1984.392600     0.119874    24.933800  ...
# std       5.41956     6.742293    18.573149     0.120070    17.532202  ...
# ...

# %%
np.array([1, 2, 3]) // 50
# Out:
# array([0, 0, 0])

# %% [markdown]
# ### SquareLimited

# %%
df_train['SquareLimited'] = 0
df_test['SquareLimited'] = 0

# %%
df_train['SquareLimited'] = ((df_train['Square'] - 1) // 50) + 1
df_test['SquareLimited'] = ((df_test['Square'] - 1) // 50) + 1

# %%
df_train.describe()
# Out:
#          DistrictId        Rooms        Square   LifeSquare  KitchenSquare  \
# count  10000.000000  10000.00000  10000.000000  7887.000000   10000.000000
# mean      50.400800      1.89010     56.323334    37.199645       6.804900
# std       43.587592      0.82176     21.040914    86.241209       3.095738
# min        0.000000      1.00000     10.000000     0.370619       4.000000
# 25%       20.000000      1.00000     41.774881    22.769832       4.000000
# 50%       36.000000      2.00000     52.513310    32.781260       6.000000
# 75%       75.000000      2.00000     65.900625    45.128803       9.000000
# max      209.000000      9.00000    641.065193  7480.592129      30.000000
#
#               Floor   HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.000000  10000.00000  10000.000000  10000.000000  10000.000000
# mean       7.727300     12.63630   1984.872400      0.118858     24.687000
# ...

# %%
df_test.describe()
# Out:
#         DistrictId        Rooms       Square   LifeSquare  KitchenSquare  \
# count  5000.000000  5000.000000  5000.000000  3959.000000    5000.000000
# mean     51.279200     1.908800    56.460103    36.158810       6.768800
# std      44.179466     0.816465    19.065028    17.825287       2.981799
# min       0.000000     1.000000    10.000000     0.333490       4.000000
# 25%      21.000000     1.000000    41.906231    23.092026       4.000000
# 50%      37.000000     2.000000    52.921340    32.925087       6.000000
# 75%      77.000000     2.000000    66.285129    45.174091       9.000000
# max     212.000000     9.000000   223.453689   303.071094      30.000000
#
#             Floor   HouseFloor    HouseYear    Ecology_1     Social_1  ...  \
# count  5000.00000  5000.000000  5000.000000  5000.000000  5000.000000  ...
# mean      7.86420    12.627200  1984.392600     0.119874    24.933800  ...
# std       5.41956     6.742293    18.573149     0.120070    17.532202  ...
# ...

# %% [markdown]
# ### LifeSquare

# %%
df_train['LifeSquare'] = df_train['Square'] - df_train['KitchenSquare'] - 2 * df_train['SquareLimited']
df_test['LifeSquare'] = df_test['Square'] - df_test['KitchenSquare'] - 2 * df_test['SquareLimited']

# %%
df_train.describe()
# Out:
#          DistrictId        Rooms        Square    LifeSquare  KitchenSquare  \
# count  10000.000000  10000.00000  10000.000000  10000.000000   10000.000000
# mean      50.400800      1.89010     56.323334     46.413234       6.804900
# std       43.587592      0.82176     21.040914     19.653982       3.095738
# min        0.000000      1.00000     10.000000      0.276663       4.000000
# 25%       20.000000      1.00000     41.774881     33.208638       4.000000
# 50%       36.000000      2.00000     52.513310     42.138458       6.000000
# 75%       75.000000      2.00000     65.900625     56.140544       9.000000
# max      209.000000      9.00000    641.065193    605.065193      30.000000
#
#               Floor   HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.000000  10000.00000  10000.000000  10000.000000  10000.000000
# mean       7.727300     12.63630   1984.872400      0.118858     24.687000
# ...

# %%
df_test.describe()
# Out:
#         DistrictId        Rooms       Square   LifeSquare  KitchenSquare  \
# count  5000.000000  5000.000000  5000.000000  5000.000000    5000.000000
# mean     51.279200     1.908800    56.460103    46.581303       6.768800
# std      44.179466     0.816465    19.065028    17.745701       2.981799
# min       0.000000     1.000000    10.000000    -6.043171       4.000000
# 25%      21.000000     1.000000    41.906231    33.366625       4.000000
# 50%      37.000000     2.000000    52.921340    42.343531       6.000000
# 75%      77.000000     2.000000    66.285129    56.701390       9.000000
# max     212.000000     9.000000   223.453689   207.138768      30.000000
#
#             Floor   HouseFloor    HouseYear    Ecology_1     Social_1  ...  \
# count  5000.00000  5000.000000  5000.000000  5000.000000  5000.000000  ...
# mean      7.86420    12.627200  1984.392600     0.119874    24.933800  ...
# std       5.41956     6.742293    18.573149     0.120070    17.532202  ...
# ...

# %% [markdown]
# ### Ecology_2, Ecology_3, Shops_2

# %%
df_train.loc[:, ['Ecology_2', 'Ecology_3', 'Shops_2']]
# Out:
#       Ecology_2 Ecology_3 Shops_2
# Id
# 14038         B         B       B
# 15053         B         B       B
# 4765          B         B       B
# 5809          B         B       B
# 10783         B         B       B
# ...         ...       ...     ...
# 77            B         B       B
# 6159          B         B       A
# 5123          B         B       A
# 5400          B         A       B
# 6306          B         B       B
#
# [10000 rows x 3 columns]

# %%
changing_numbers = {'A': 0, 'B': 1}

# %%
df_train['Ecology_2'] = df_train['Ecology_2'].map(changing_numbers)
df_train['Ecology_3'] = df_train['Ecology_3'].map(changing_numbers)
df_train['Shops_2'] = df_train['Shops_2'].map(changing_numbers)

# %%
df_test['Ecology_2'] = df_test['Ecology_2'].map(changing_numbers)
df_test['Ecology_3'] = df_test['Ecology_3'].map(changing_numbers)
df_test['Shops_2'] = df_test['Shops_2'].map(changing_numbers)

# %%
df_train
# Out:
#        DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# Id
# 14038          35    2.0  47.981561   39.981561            6.0      7
# 15053          41    3.0  65.683640   53.683640            8.0      7
# 4765           53    2.0  44.947953   38.947953            4.0      8
# 5809           58    2.0  53.352981   40.352981            9.0      8
# 10783          99    1.0  39.649192   30.649192            7.0     11
# ...           ...    ...        ...         ...            ...    ...
# 77             32    2.0  50.401785   43.401785            5.0      5
# 6159           18    1.0  41.521546   30.521546            9.0     13
# 5123           27    1.0  47.939008   41.939008            4.0     12
# 5400           75    2.0  43.602562   33.602562            8.0      1
# 6306          128    1.0  38.666645   28.666645            8.0      7
#
#        HouseFloor  HouseYear  Ecology_1  Ecology_2  ...  Shops_2  \
# ...

# %%
df_test
# Out:
#        DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# Id
# 725            58    2.0  49.882643   41.882643            6.0      6
# 15856          74    2.0  69.263183   61.263183            4.0      1
# 5480          190    1.0  13.597819   -0.402181           12.0      2
# 15664          47    2.0  73.046609   60.046609            9.0     22
# 14275          27    1.0  47.527111   41.527111            4.0     17
# ...           ...    ...        ...         ...            ...    ...
# 8180           11    3.0  67.133911   57.133911            6.0      5
# 4695            1    1.0  40.198472   28.198472           10.0     12
# 5783           12    3.0  77.842178   64.842178            9.0     22
# 4780           62    2.0  81.305222   73.305222            4.0      1
# 12504          30    2.0  60.555693   52.555693            4.0     10
#
#        HouseFloor  HouseYear  Ecology_1  Ecology_2  ...  Shops_2  \
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Очистка данных

# %% [markdown]
# ### теперь обработаем пропущенные значения

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 14038 to 6306
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DistrictId                 10000 non-null  int64
#  1   Rooms                      10000 non-null  float64
#  2   Square                     10000 non-null  float64
#  3   LifeSquare                 10000 non-null  float64
#  4   KitchenSquare              10000 non-null  float64
#  5   Floor                      10000 non-null  int64
#  6   HouseFloor                 10000 non-null  float64
#  7   HouseYear                  10000 non-null  int64
#  8   Ecology_1                  10000 non-null  float64
#  9   Ecology_2                  10000 non-null  int64
#  10  Ecology_3                  10000 non-null  int64
#  11  Social_1                   10000 non-null  int64
#  12  Social_2                   10000 non-null  int64
# ...

# %%
df_train['Healthcare_1'].describe()
# Out:
# count    5202.000000
# mean     1142.904460
# std      1021.517264
# min         0.000000
# 25%       350.000000
# 50%       900.000000
# 75%      1548.000000
# max      4849.000000
# Name: Healthcare_1, dtype: float64

# %%
median_healthcare_1 = df_train['Healthcare_1'].median()

# %%
df_train['Healthcare_1'] = df_train['Healthcare_1'].fillna(median_healthcare_1)
df_test['Healthcare_1'] = df_test['Healthcare_1'].fillna(median_healthcare_1)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 14038 to 6306
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DistrictId                 10000 non-null  int64
#  1   Rooms                      10000 non-null  float64
#  2   Square                     10000 non-null  float64
#  3   LifeSquare                 10000 non-null  float64
#  4   KitchenSquare              10000 non-null  float64
#  5   Floor                      10000 non-null  int64
#  6   HouseFloor                 10000 non-null  float64
#  7   HouseYear                  10000 non-null  int64
#  8   Ecology_1                  10000 non-null  float64
#  9   Ecology_2                  10000 non-null  int64
#  10  Ecology_3                  10000 non-null  int64
#  11  Social_1                   10000 non-null  int64
#  12  Social_2                   10000 non-null  int64
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5000 entries, 725 to 12504
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DistrictId                 5000 non-null   int64
#  1   Rooms                      5000 non-null   float64
#  2   Square                     5000 non-null   float64
#  3   LifeSquare                 5000 non-null   float64
#  4   KitchenSquare              5000 non-null   float64
#  5   Floor                      5000 non-null   int64
#  6   HouseFloor                 5000 non-null   float64
#  7   HouseYear                  5000 non-null   int64
#  8   Ecology_1                  5000 non-null   float64
#  9   Ecology_2                  5000 non-null   int64
#  10  Ecology_3                  5000 non-null   int64
#  11  Social_1                   5000 non-null   int64
#  12  Social_2                   5000 non-null   int64
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Разбиение данных на train и test

# %%
df_train
# Out:
#        DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# Id
# 14038          35    2.0  47.981561   39.981561            6.0      7
# 15053          41    3.0  65.683640   53.683640            8.0      7
# 4765           53    2.0  44.947953   38.947953            4.0      8
# 5809           58    2.0  53.352981   40.352981            9.0      8
# 10783          99    1.0  39.649192   30.649192            7.0     11
# ...           ...    ...        ...         ...            ...    ...
# 77             32    2.0  50.401785   43.401785            5.0      5
# 6159           18    1.0  41.521546   30.521546            9.0     13
# 5123           27    1.0  47.939008   41.939008            4.0     12
# 5400           75    2.0  43.602562   33.602562            8.0      1
# 6306          128    1.0  38.666645   28.666645            8.0      7
#
#        HouseFloor  HouseYear  Ecology_1  Ecology_2  ...  Shops_2  \
# ...

# %%
df_test
# Out:
#        DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# Id
# 725            58    2.0  49.882643   41.882643            6.0      6
# 15856          74    2.0  69.263183   61.263183            4.0      1
# 5480          190    1.0  13.597819   -0.402181           12.0      2
# 15664          47    2.0  73.046609   60.046609            9.0     22
# 14275          27    1.0  47.527111   41.527111            4.0     17
# ...           ...    ...        ...         ...            ...    ...
# 8180           11    3.0  67.133911   57.133911            6.0      5
# 4695            1    1.0  40.198472   28.198472           10.0     12
# 5783           12    3.0  77.842178   64.842178            9.0     22
# 4780           62    2.0  81.305222   73.305222            4.0      1
# 12504          30    2.0  60.555693   52.555693            4.0     10
#
#        HouseFloor  HouseYear  Ecology_1  Ecology_2  ...  Shops_2  \
# ...

# %%
y_train
# Out:
#                Price
# Id
# 14038  184966.930730
# 15053  300009.450063
# 4765   220925.908524
# 5809   175616.227217
# 10783  150226.531644
# ...              ...
# 77     196684.316040
# 6159   189050.289571
# 5123   159143.805370
# 5400   181595.339808
# 6306   218714.077615
#
# [10000 rows x 1 columns]

# %% [markdown]
# ---

# %% [markdown]
# # Построение ML моделей

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from lightgbm import LGBMRegressor

# %% [markdown]
# ### LinearRegression

# %%
lr_model = LinearRegression()

# %%
lr_model.fit(df_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr_model.predict(df_test)

# %%
Id_df['Price'] = y_pred

# %%
Id_df
# Out:
#          Id          Price
# 0       725  175237.696865
# 1     15856  194158.262937
# 2      5480  293477.190670
# 3     15664  271486.169430
# 4     14275  122743.319268
# ...     ...            ...
# 4995   8180  254312.920314
# 4996   4695  138430.243451
# 4997   5783  350277.729291
# 4998   4780  218539.368930
# 4999  12504  214663.060163
#
# [5000 rows x 2 columns]

# %%
Id_df.to_csv('answer_lr.csv', index=False)

# %%
Id_df.drop('Price', axis=1)
# Out:
#          Id
# 0       725
# 1     15856
# 2      5480
# 3     15664
# 4     14275
# ...     ...
# 4995   8180
# 4996   4695
# 4997   5783
# 4998   4780
# 4999  12504
#
# [5000 rows x 1 columns]

# %% [markdown]
# ### DecisionTreeRegressor

# %%
model_dt = DecisionTreeRegressor(criterion='squared_error',
                                 max_depth=20, 
                                 min_samples_leaf=50, 
                                 random_state=42)
model_dt.fit(df_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=20, min_samples_leaf=50, random_state=42)

# %%
y_pred = model_dt.predict(df_test)

# %%
Id_df['Price'] = y_pred

# %%
Id_df.to_csv('answer_dt.csv', index=False)

# %%
Id_df.drop('Price', axis=1)
# Out:
#          Id
# 0       725
# 1     15856
# 2      5480
# 3     15664
# 4     14275
# ...     ...
# 4995   8180
# 4996   4695
# 4997   5783
# 4998   4780
# 4999  12504
#
# [5000 rows x 1 columns]

# %% [markdown]
# ### RandomForestRegressor

# %%
rf_model = RandomForestRegressor(criterion='squared_error',
                                 max_depth=20, 
                                 min_samples_leaf=30, 
                                 random_state=42,
                                 n_estimators=100 
                                 )
rf_model.fit(df_train, y_train)
# Out:
# /Users/macbook/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(max_depth=20, min_samples_leaf=30, random_state=42)

# %%
y_pred = rf_model.predict(df_test)

# %%
Id_df['Price'] = y_pred

# %%
Id_df.to_csv('answer_rf.csv', index=False)

# %%
Id_df.drop('Price', axis=1)
# Out:
#          Id
# 0       725
# 1     15856
# 2      5480
# 3     15664
# 4     14275
# ...     ...
# 4995   8180
# 4996   4695
# 4997   5783
# 4998   4780
# 4999  12504
#
# [5000 rows x 1 columns]

# %% [markdown]
# ### LGBMRegressor

# %%
lgb_model = LGBMRegressor(objective='regression_l2',
                          metric='mse',
                          max_depth=20, 
                          min_child_samples=10,
                          random_state=42,
                          n_estimators=100)
lgb_model.fit(df_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000903 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1371
# [LightGBM] [Info] Number of data points in the train set: 10000, number of used features: 26
# [LightGBM] [Info] Start training from score 214138.857336
# /Users/macbook/Library/Python/3.9/lib/python/site-packages/sklearn/utils/_tags.py:354: FutureWarning: The LGBMRegressor or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(
# ...

# %%
y_pred = rf_model.predict(df_test)

# %%
Id_df['Price'] = y_pred

# %%
Id_df.to_csv('answer_lgbm.csv', index=False)

# %%
Id_df.drop('Price', axis=1)
# Out:
#          Id
# 0       725
# 1     15856
# 2      5480
# 3     15664
# 4     14275
# ...     ...
# 4995   8180
# 4996   4695
# 4997   5783
# 4998   4780
# 4999  12504
#
# [5000 rows x 1 columns]

# %%
Id_df['Price'] = y_pred

# %%
Id_df.to_csv('answer_lgbm.csv', index=False)

# %%
Id_df.drop('Price', axis=1)
# Out:
#          Id
# 0       725
# 1     15856
# 2      5480
# 3     15664
# 4     14275
# ...     ...
# 4995   8180
# 4996   4695
# 4997   5783
# 4998   4780
# 4999  12504
#
# [5000 rows x 1 columns]

# %% [markdown]
# ### Кросс-валидация

# %%
from sklearn.model_selection import KFold, GridSearchCV

# %%
lgb_model = LGBMRegressor(objective='regression_l2',
                          min_child_samples=30,
                          random_state=42,
                          )

# %%
params = {'n_estimators': [50, 100, 200, 400],
          'max_depth': [3, 5, 7, 10]}

gs = GridSearchCV(lgb_model, params, 
                  scoring='r2', 
                  cv=KFold(n_splits=5, 
                           random_state=21, 
                           shuffle=True),
                  n_jobs=-1
                  )
gs.fit(df_train, y_train)
# Out:
# /Users/macbook/Library/Python/3.9/lib/python/site-packages/sklearn/utils/_tags.py:354: FutureWarning: The LGBMRegressor or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(
# ...

# %%
res = pd.DataFrame(gs.cv_results_)
res
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.291598      0.026268         0.004446        0.000778
# 1        1.208619      0.175694         0.006710        0.002759
# 2        2.405155      0.206239         0.014296        0.002979
# 3        5.266606      0.421758         0.013274        0.002622
# 4        2.366423      0.173834         0.008654        0.007459
# 5        3.137613      0.265471         0.006350        0.002897
# 6        5.728688      0.089369         0.005817        0.000644
# 7        9.787460      0.148482         0.009566        0.002727
# 8        2.387250      0.073858         0.003937        0.000633
# 9        4.564819      0.078018         0.011105        0.005501
# 10       7.462156      0.305951         0.007826        0.001650
# 11      14.688491      0.350703         0.020808        0.006512
# 12       3.319932      0.144685         0.006910        0.002770
# ...

# %%
gs.best_params_
# Out:
# {'max_depth': 7, 'n_estimators': 200}

# %%
final_model = LGBMRegressor(objective='regression_l2',
                          max_depth=7, 
                          min_child_samples=10,
                          random_state=42,
                          n_estimators=200)
final_model.fit(df_train, y_train)

y_pred = final_model.predict(df_test)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001065 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1371
# [LightGBM] [Info] Number of data points in the train set: 10000, number of used features: 26
# [LightGBM] [Info] Start training from score 214138.857336
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
Id_df['Price'] = y_pred

# %%
Id_df.to_csv('answer_lgbm_cv.csv', index=False)

# %%
Id_df.drop('Price', axis=1)
# Out:
#          Id
# 0       725
# 1     15856
# 2      5480
# 3     15664
# 4     14275
# ...     ...
# 4995   8180
# 4996   4695
# 4997   5783
# 4998   4780
# 4999  12504
#
# [5000 rows x 1 columns]

# %% [markdown]
# ### Catboost

# %%
from catboost import CatBoostRegressor

# %%
final_model = CatBoostRegressor(
    iterations=200,          # Количество деревьев (эквивалент n_estimators)
    depth=7,                # Максимальная глубина деревьев
    learning_rate=0.1,      # Скорость обучения (по умолчанию 0.03)
    l2_leaf_reg=3,          # Регуляризация L2 (аналог min_child_samples)
    random_state=42,        # Случайное состояние для воспроизводимости
    loss_function='RMSE'    # Функция потерь
)

final_model.fit(df_train, y_train)
# Out:
# 0:	learn: 87796.8303514	total: 2.49ms	remaining: 496ms
# 1:	learn: 83428.2309688	total: 4.63ms	remaining: 458ms
# 2:	learn: 79685.9323307	total: 6.58ms	remaining: 432ms
# 3:	learn: 76349.6759706	total: 8.52ms	remaining: 418ms
# 4:	learn: 73220.2703210	total: 10.5ms	remaining: 410ms
# 5:	learn: 70723.3873728	total: 12.3ms	remaining: 397ms
# 6:	learn: 68361.4201891	total: 14.2ms	remaining: 392ms
# 7:	learn: 66604.5341428	total: 16.2ms	remaining: 388ms
# 8:	learn: 64777.2912252	total: 19ms	remaining: 404ms
# 9:	learn: 63172.0876892	total: 21ms	remaining: 399ms
# 10:	learn: 61994.4909868	total: 22.9ms	remaining: 393ms
# 11:	learn: 60705.3229358	total: 25.1ms	remaining: 393ms
# 12:	learn: 59622.0920584	total: 26.9ms	remaining: 387ms
# 13:	learn: 58511.4260395	total: 28.7ms	remaining: 381ms
# 14:	learn: 57587.3085518	total: 30.5ms	remaining: 376ms
# 15:	learn: 56688.5834321	total: 32.6ms	remaining: 375ms
# 16:	learn: 55864.1441468	total: 34.5ms	remaining: 372ms
# ...

# %%
y_pred = final_model.predict(df_test)

# %%
Id_df['Price'] = y_pred

# %%
Id_df.to_csv('answer_cb.csv', index=False)

# %%
Id_df.drop('Price', axis=1)
# Out:
#          Id
# 0       725
# 1     15856
# 2      5480
# 3     15664
# 4     14275
# ...     ...
# 4995   8180
# 4996   4695
# 4997   5783
# 4998   4780
# 4999  12504
#
# [5000 rows x 1 columns]

# %% [markdown]
# ### Кросс валидация

# %%
final_model = CatBoostRegressor(
    learning_rate=0.1,      # Скорость обучения (по умолчанию 0.03)
    l2_leaf_reg=30,          # Регуляризация L2 (аналог min_child_samples)
    random_state=42,        # Случайное состояние для воспроизводимости
    loss_function='RMSE'    # Функция потерь
)

# %%
params = {'iterations': [50, 100, 200, 400],
          'depth': [3, 5, 7, 10]}

gs = GridSearchCV(final_model, params, 
                  scoring='r2', 
                  cv=KFold(n_splits=5, 
                           random_state=21, 
                           shuffle=True),
                  n_jobs=-1
                  )
gs.fit(df_train, y_train)
# Out:
# 0:	learn: 88042.0863686	total: 57.3ms	remaining: 2.81s
# 0:	learn: 88130.2110268	total: 57.7ms	remaining: 5.71s
# 0:	learn: 88499.7265417	total: 58.4ms	remaining: 5.79s
# 0:	learn: 88042.0863686	total: 58.6ms	remaining: 5.8s
# 0:	learn: 89137.2339001	total: 58.8ms	remaining: 5.82s
# 1:	learn: 84099.7172674	total: 59.1ms	remaining: 1.42s
# 1:	learn: 84281.8095885	total: 59.4ms	remaining: 2.91s
# 1:	learn: 84721.0541324	total: 60ms	remaining: 2.94s
# 2:	learn: 81044.7050227	total: 60.5ms	remaining: 1.96s
# 1:	learn: 84099.7172674	total: 60.7ms	remaining: 2.97s
# 1:	learn: 85119.7396054	total: 61.2ms	remaining: 3s
# 2:	learn: 80815.6092029	total: 61.1ms	remaining: 957ms
# 2:	learn: 80815.6092029	total: 61.9ms	remaining: 2s
# 2:	learn: 81513.4275778	total: 62.2ms	remaining: 2.01s
# 0:	learn: 88337.4679112	total: 57.4ms	remaining: 2.81s
# 3:	learn: 78510.0981704	total: 62.3ms	remaining: 1.5s
# 0:	learn: 89137.2339001	total: 56.9ms	remaining: 2.79s
# ...

# %%
gs.best_params_
# Out:
# {'depth': 10, 'iterations': 400}

# %%
final_model = CatBoostRegressor(
    iterations=400,          # Количество деревьев (эквивалент n_estimators)
    depth=10,                # Максимальная глубина деревьев
    learning_rate=0.1,      # Скорость обучения (по умолчанию 0.03)
    l2_leaf_reg=30,          # Регуляризация L2 (аналог min_child_samples)
    random_state=42,        # Случайное состояние для воспроизводимости
    loss_function='RMSE'    # Функция потерь
)

final_model.fit(df_train, y_train)
# Out:
# 0:	learn: 88708.8870813	total: 7.6ms	remaining: 3.03s
# 1:	learn: 84788.9912166	total: 14.3ms	remaining: 2.84s
# 2:	learn: 81229.7162384	total: 20.9ms	remaining: 2.77s
# 3:	learn: 78064.3506798	total: 24.6ms	remaining: 2.44s
# 4:	learn: 75257.0332074	total: 30.4ms	remaining: 2.4s
# 5:	learn: 72456.6874871	total: 36.7ms	remaining: 2.41s
# 6:	learn: 70343.0263834	total: 42.9ms	remaining: 2.41s
# 7:	learn: 68343.9413831	total: 48.9ms	remaining: 2.39s
# 8:	learn: 66583.6147849	total: 54.9ms	remaining: 2.38s
# 9:	learn: 64984.4245206	total: 60.9ms	remaining: 2.37s
# 10:	learn: 63541.1007867	total: 66.6ms	remaining: 2.35s
# 11:	learn: 62295.0746607	total: 72.6ms	remaining: 2.35s
# 12:	learn: 61062.6717952	total: 78.4ms	remaining: 2.33s
# 13:	learn: 59988.3065060	total: 84.5ms	remaining: 2.33s
# 14:	learn: 59049.0164914	total: 90.7ms	remaining: 2.33s
# 15:	learn: 58127.8615047	total: 97.1ms	remaining: 2.33s
# 16:	learn: 57422.9033224	total: 103ms	remaining: 2.33s
# ...

# %%
y_pred = final_model.predict(df_test)

# %%
Id_df['Price'] = y_pred

# %%
Id_df.to_csv('answer_cb_cv.csv', index=False)
